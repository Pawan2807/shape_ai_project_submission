# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-459b50c9-7a94-4a27-a05b-3befc4297fca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-459b50c9-7a94-4a27-a05b-3befc4297fca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Train.csv to Google_Stock_Price_Train (1).csv

# %%
training_data = pd.read_csv('Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# feature scaling

from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler(feature_range = (0, 1))
training_data = mm.fit_transform(training_data)

# %%
# Getting the inputs and outputs

x_train = training_data[0:1257]
y_train = training_data[1:1258]

print(x_train.shape)
print(y_train.shape)
# Out:
# (1257, 1)
# (1257, 1)

# %%
# reshaping

x_train = np.reshape(x_train, (1257, 1, 1))

print(x_train.shape)
# Out:
# (1257, 1, 1)

# %%
# importing the keras libraries and packages

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# initializing the model
model = Sequential()

# adding the input layer and the LSTM layer
model.add(LSTM(units = 4, activation = 'sigmoid', input_shape = (None, 1)))

# adding the output layer
model.add(Dense(units = 1))

# compiling the model
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# fitting the RNN to the training data
model.fit(x_train, y_train, batch_size = 32, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 2s 2ms/step - loss: 0.3226
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.2355
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1744
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1343
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.1172
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0977
# Epoch 7/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0887
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0845
# Epoch 9/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0781
# Epoch 10/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0800
# Epoch 11/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0790
# Epoch 12/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 13/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0773
# Epoch 14/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0769
# Epoch 15/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0744
# Epoch 16/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0743
# Epoch 17/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0727
# Epoch 18/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0690
# Epoch 19/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0681
# Epoch 20/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0672
# Epoch 21/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0646
# Epoch 22/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0627
# Epoch 23/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0601
# Epoch 24/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0612
# Epoch 25/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0571
# Epoch 26/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0596
# Epoch 27/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0539
# Epoch 28/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0525
# Epoch 29/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0539
# Epoch 30/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0509
# Epoch 31/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0470
# Epoch 32/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0447
# Epoch 33/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0437
# Epoch 34/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0435
# Epoch 35/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 36/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0385
# Epoch 37/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0359
# Epoch 38/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0348
# Epoch 39/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0325
# Epoch 40/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0323
# Epoch 41/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0300
# Epoch 42/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0259
# Epoch 43/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 44/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0231
# Epoch 45/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0228
# Epoch 46/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 47/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 48/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 49/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0157
# Epoch 50/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0148
# Epoch 51/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 52/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 53/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 54/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 55/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0083
# Epoch 56/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 57/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 58/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 59/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 60/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 61/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 62/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 63/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 64/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 65/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 66/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 67/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 68/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 69/200
# 40/40 [==============================] - 0s 2ms/step - loss: 9.7756e-04
# Epoch 70/200
# 40/40 [==============================] - 0s 2ms/step - loss: 8.4688e-04
# Epoch 71/200
# 40/40 [==============================] - 0s 2ms/step - loss: 7.8203e-04
# Epoch 72/200
# 40/40 [==============================] - 0s 2ms/step - loss: 6.4554e-04
# Epoch 73/200
# 40/40 [==============================] - 0s 2ms/step - loss: 5
200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8969e-04
# Epoch 178/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6170e-04
# Epoch 179/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4657e-04
# Epoch 180/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.5912e-04
# Epoch 181/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.1633e-04
# Epoch 182/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8951e-04
# Epoch 183/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.4384e-04
# Epoch 184/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8490e-04
# Epoch 185/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.3238e-04
# Epoch 186/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7408e-04
# Epoch 187/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6443e-04
# Epoch 188/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5006e-04
# Epoch 189/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5293e-04
# Epoch 190/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.7264e-04
# Epoch 191/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.2328e-04
# Epoch 192/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5202e-04
# Epoch 193/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5925e-04
# Epoch 194/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.8554e-04
# Epoch 195/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6792e-04
# Epoch 196/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5652e-04
# Epoch 197/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.5608e-04
# Epoch 198/200
# 40/40 [==============================] - 0s 2ms/step - loss: 3.4481e-04
# Epoch 199/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6742e-04
# Epoch 200/200
# 40/40 [==============================] - 0s 2ms/step - loss: 2.6701e-04

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bb17c47e-7a8c-44aa-8b1e-ed0be09548be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bb17c47e-7a8c-44aa-8b1e-ed0be09548be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Google_Stock_Price_Test.csv to Google_Stock_Price_Test (1).csv

# %%
# getting the real stock of 2017 i.e., importing the test dataset

test_data = pd.read_csv('Google_Stock_Price_Test.csv')
real_stock_price = test_data.iloc[:,1:2]
real_stock_price.head()
# Out:
#      Open
# 0  778.81
# 1  788.36
# 2  786.08
# 3  795.26
# 4  806.40

# %%
# getting the predicted stock price of 2017

inputs = real_stock_price
inputs = mm.transform(inputs)
inputs = np.reshape(inputs, (20, 1, 1))


predicted_stock_price = model.predict(inputs)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
predicted_stock_price
# Out:
# array([[776.0058 ],
#        [784.0451 ],
#        [782.13745],
#        [789.7726 ],
#        [798.8751 ],
#        [800.0548 ],
#        [797.741  ],
#        [799.4734 ],
#        [799.74805],
#        [799.425  ],
#        [798.3975 ],
#        [797.8384 ],
#        [799.2876 ],
#        [799.5623 ],
#        [811.55585],
#        [817.27014],
#        [823.5711 ],
#        [821.19763],
#        [805.50854],
#        [791.09094]], dtype=float32)

# %%
# visualizing the results

plt.plot(real_stock_price, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# getting the real stock price of 2012 - 2016

training_data = pd.read_csv('Google_Stock_Price_Train.csv')

training_data.shape
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data = training_data.iloc[:, 1:2]

training_data.shape
training_data.head()
# Out:
#      Open
# 0  325.25
# 1  331.27
# 2  329.83
# 3  328.34
# 4  322.04

# %%
# getting the predicted stock price of 2012-2016

predicted_stock_price = model.predict(x_train)
predicted_stock_price = mm.inverse_transform(predicted_stock_price)

# %%
# visualizing the whole training data results

plt.plot(training_data, color = 'red', label = 'Real Google Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted Google Stock Price')
plt.title('Stock Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %% [markdown]
# **BY- PAWAN DEEP**
